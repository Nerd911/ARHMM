# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
import ssm
import matplotlib.pyplot as plt
import plotly.express as px
import pickle
import scipy
import scipy.io
import tsfresh
import dtale
import os
px.set_mapbox_access_token("pk.eyJ1IjoibWlrb2xhanNsdXBpbnNraSIsImEiOiJjazJ5dDI0MWEwOTA3M2hxanRwbmo4NDRuIn0.NSbj3B1Bm6fC5QUP3s-BjQ")
import plotly.io as pio
pio.renderers.default = "iframe"
import dask
from lib.huawei import load_data, load_motion, load_ambient, load_battery, load_api, load_label
import tables
from ssm.util import random_rotation, find_permutation
import logging
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.feature_selection import mutual_info_classif
logging.basicConfig(filename='huawei_hmm.log', level=logging.DEBUG)

# %%
MODELS_PATH = "../Models/hmm/"

# %%
with open("../Data/huawei-competition/selected_features.pickle", "rb") as ifile:
    selected_features = pickle.load(ifile)

# %%
transportation_modes = np.array(["still", "walk", "run", "bike", "car", "bus", "train", "subway"])

# %%
data = []
for selected_feature in selected_features:
#     file_path = os.path.join("../Data/2012.01.17-huawei/splitted/", f"1.3a-stationary_50ms__{selected_feature}.csv")
#     df = pd.read_csv(file_path, parse_dates = ["DATETIME_UTC"], index_col="DATETIME_UTC")
    a = np.load(os.path.join("../", selected_feature))
    data.append(a)
#     print(df.shape)
data = np.stack(data, axis=1)

# %%
labels = np.load("../Data/huawei-competition/resampled/Label.npy")[:,-1].astype(int) - 1

# %%
order = np.loadtxt("../Data/huawei-competition/train_order.txt").astype(int)

# %%
data_ordered = np.zeros(data.shape)

# %%
data_ordered[order - 1, :] = data

# %%
labels_ordered = np.zeros(labels.shape)
labels_ordered[order - 1] = labels

# %%
n = int(data_ordered.shape[0]*0.25)
m = int(data_ordered.shape[0]*0.5)
X_train = data_ordered[m:]
y_train = labels_ordered[m:]
X_val = data_ordered[:n]
y_val = labels_ordered[:n]
X_test = data_ordered[n:m]
y_test = labels_ordered[n:m]

# %%
def load_model(path):
    with open(path, "rb") as ifile:
        model_dic = pickle.load(ifile)
    return model_dic

# %%
models_dic = {}
for f in os.listdir(MODELS_PATH):
    models_dic[f] = load_model(os.path.join(MODELS_PATH, f))

# %%
for f in os.listdir("../Models/hmm_parallel/"):
    models_dic[f] = load_model(os.path.join("../Models/hmm_parallel/", f))

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6., 7.]),
#  array([1176,  949,  338, 1110, 1195,  993, 1455,  939]))

# %%
def plot_states(data_z, z_est, label, prefix):
    titles = ["True", label]
    states_list = [data_z, z_est]
    fig, axs = plt.subplots(2,1, figsize=(6,4))
    for (i, ax, states) in zip(range(len(axs)), axs, states_list):
        ax.imshow(states[None,:], aspect="auto")
        ax.set_yticks([])
        ax.set_title(titles[i])
        if i < (len(axs) - 1):
            ax.set_xticks([])

    plt.suptitle(f"{titles[0]} and {titles[1]}", va="baseline")
    plt.tight_layout()
    plt.savefig(f"../Plots/hmm/{prefix}_{titles[0]}_{titles[1]}.pdf")
    plt.show()

# %%
mutual_informations = {}

# %%
for f_name, model_dic in models_dic.items():
    prefix = f_name[:-7]
    print(prefix)
    model = model_dic["arhmm"]
    lls = model_dic["hmm_lls"]
    most_likely = model_dic["most_likely"]
    mutual_info = mutual_info_classif(X_train, most_likely)
    mutual_informations[f_name+"_validation"] = mutual_info
#     plt.plot(lls)
#     plt.show()
#     l = len(lls) // 10
#     plt.plot(lls[l:])
#     plt.show()
#     plot_states(y_train, most_likely, "Estimated", prefix)
#     print(accuracy_score(y_train, most_likely))
#     disp = ConfusionMatrixDisplay(confusion_matrix(y_train, most_likely))
#     disp.plot()
#     plt.show()
#     y_predicted = model.most_likely_states(X_val)
#     plot_states(y_val, y_predicted, "Predicted", prefix)
#     print(accuracy_score(y_val, y_predicted))
#     disp = ConfusionMatrixDisplay(confusion_matrix(y_val, y_predicted))
#     disp.plot()
#     plt.show()
# Out:
# huawei_hmm_recurrent_diagonal_gaussian_10_10000_random
# huawei_hmm_recurrent_diagonal_gaussian_1000_10000_random
# huawei_hmm_recurrent_diagonal_gaussian_1000_10000_kmeans
# huawei_hmm_recurrent_diagonal_gaussian_10000_10000_random
# huawei_hmm_recurrent_diagonal_gaussian_10000_10000_kmeans
# huawei_hmm_recurrent_diagonal_gaussian_100000_10000_random
# huawei_hmm_standard_diagonal_gaussian_10000_10000_random
# huawei_hmm_standard_diagonal_gaussian_10000_10000_kmeans
# huawei_reduced_hmm_recurrent_diagonal_gaussian_10000_10000_random
# huawei_reduced_hmm_recurrent_gaussian_10000_10000_random
# huawei_reduced_hmm_recurrent_no_input_ar_10000_10000_random
# huawei_reduced_hmm_recurrent_robust_ar_10000_10000_random
# huawei_reduced_hmm_recurrent_diagonal_gaussian_10000_10000_kmeans
# huawei_reduced_hmm_recurrent_gaussian_10000_10000_kmeans
# huawei_reduced_hmm_standard_diagonal_gaussian_10000_10000_random
# huawei_reduced_hmm_standard_diagonal_gaussian_10000_10000_kmeans
# huawei_reduced_hmm_standard_autoregressive_10000_10000_random
# huawei_reduced_hmm_recurrent_no_input_ar_10000_10000_kmeans
# huawei_reduced_hmm_standard_autoregressive_10000_10000_kmeans
# huawei_reduced_hmm_recurrent_autoregressive_10000_10000_kmeans
# huawei_reduced_hmm_recurrent_diagonal_robust_ar_10000_10000_random
# huawei_reduced_hmm_standard_no_input_ar_10000_10000_kmeans
# huawei_reduced_hmm_standard_diagonal_ar_10000_10000_kmeans
# huawei_reduced_hmm_recurrent_diagonal_ar_10000_10000_random
# huawei_reduced_hmm_standard_diagonal_robust_ar_10000_10000_random
# huawei_reduced_hmm_standard_robust_ar_10000_10000_random

# %%
feature_names = []
for i, feature in enumerate(selected_features):
    feature_name = feature.split("-")[-1].split(".")[0]
    feature_names.append(f"{i}_{feature_name}")

# %%
feature_names
# Out:
# ['0_LAcc_magnitude_q2',
#  '1_Acc_magnitude_hist_0',
#  '2_Acc_magnitude_max_signal1',
#  '3_LAcc_y_q1',
#  '4_LAcc_y_hist_0',
#  '5_Acc_y_Acc_magnitude_cov',
#  '6_LAcc_y_hist_9',
#  '7_Acc_magnitude_hist_9',
#  '8_Acc_magnitude_entropy',
#  '9_Acc_magnitude_Acc_derotated_z_cov',
#  '10_LAcc_z_hist_0',
#  '11_LAcc_x_hist_0',
#  '12_Acc_y_hist_9',
#  '13_LAcc_x_max_signal1',
#  '14_Acc_magnitude_Gyr_magnitude_cov',
#  '15_Acc_y_LAcc_y_cov',
#  '16_Acc_magnitude_LAcc_magnitude_cov',
#  '17_Acc_magnitude_hist_1',
#  '18_Acc_derotated_z_max_signal2',
#  '19_LAcc_z_hist_9',
#  '20_LAcc_y_Acc_magnitude_cov',
#  '21_Acc_z_Acc_magnitude_cov',
#  '22_Acc_magnitude_Gra_magnitude_cov',
#  '23_LAcc_x_hist_9',
#  '24_Acc_magnitude_hist_2',
#  '25_Gyr_y_hist_0',
#  '26_LAcc_z_Acc_magnitude_cov',
#  '27_LAcc_magnitude_hist_9',
#  '28_Gyr_x_Acc_magnitude_cov',
#  '29_LAcc_z_pitch_cov',
#  '30_Acc_z_LAcc_z_cov',
#  '31_LAcc_y_Gyr_magnitude_cov',
#  '32_Gyr_y_max_signal1',
#  '33_LAcc_z_Acc_y_cov',
#  '34_Gyr_y_LAcc_y_cov',
#  '35_LAcc_x_Acc_y_cov',
#  '36_LAcc_y_Acc_derotated_z_cov',
#  '37_Gyr_y_Acc_magnitude_cov',
#  '38_Gyr_x_LAcc_z_cov',
#  '39_Gyr_x_LAcc_y_cov',
#  '40_LAcc_x_Acc_magnitude_cov',
#  '41_Acc_derotated_z_hist_9',
#  '42_LAcc_x_LAcc_y_cov',
#  '43_LAcc_x_LAcc_z_cov',
#  '44_Gra_y_energy',
#  '45_Gyr_x_LAcc_x_cov',
#  '46_Acc_x_LAcc_y_cov',
#  '47_LAcc_y_Gra_magnitude_cov',
#  '48_Acc_x_Acc_magnitude_cov',
#  '49_Acc_z_LAcc_y_cov',
#  '50_Acc_y_mean',
#  '51_Acc_magnitude_Acc_derotated_x_cov',
#  '52_Acc_x_LAcc_x_cov',
#  '53_Acc_y_Gra_magnitude_cov',
#  '54_LAcc_y_max',
#  '55_LAcc_z_LAcc_y_cov',
#  '56_Acc_magnitude_pitch_cov',
#  '57_Acc_x_hist_9',
#  '58_Gyr_x_hist_0',
#  '59_Gyr_z_LAcc_y_cov',
#  '60_LAcc_z_Gyr_y_cov',
#  '61_Gyr_z_Acc_magnitude_cov',
#  '62_Gyr_z_max_signal3',
#  '63_Gyr_x_Acc_y_cov',
#  '64_Acc_y_Acc_derotated_z_cov',
#  '65_Acc_magnitude_Acc_derotated_y_cov',
#  '66_Acc_derotated_x_hist_0',
#  '67_Gyr_z_LAcc_z_cov',
#  '68_Acc_derotated_y_max_signal2',
#  '69_LAcc_y_pitch_cov',
#  '70_Gra_magnitude_energy',
#  '71_Acc_y_LAcc_magnitude_cov',
#  '72_Acc_y_Gyr_y_cov',
#  '73_LAcc_x_Gra_z_cov',
#  '74_Gyr_x_Acc_derotated_z_cov',
#  '75_Acc_x_LAcc_z_cov',
#  '76_LAcc_y_hist_2',
#  '77_Acc_y_Gyr_magnitude_cov',
#  '78_Acc_magnitude_q1',
#  '79_LAcc_x_max',
#  '80_Acc_z_Gyr_x_cov',
#  '81_Acc_x_Gyr_x_cov',
#  '82_Gyr_x_pitch_cov',
#  '83_Acc_z_Gyr_z_cov',
#  '84_pitch_max_signal1',
#  '85_LAcc_x_pitch_cov',
#  '86_pitch_hist_0',
#  '87_Gyr_z_hist_0',
#  '88_LAcc_x_hist_1',
#  '89_Gra_z_LAcc_y_cov',
#  '90_Acc_z_LAcc_x_cov',
#  '91_Gyr_z_LAcc_x_cov',
#  '92_Gyr_magnitude_hist_9',
#  '93_LAcc_x_Gyr_magnitude_cov',
#  '94_Acc_derotated_y_hist_0',
#  '95_LAcc_y_Mag_z_cov',
#  '96_LAcc_y_Acc_derotated_x_cov',
#  '97_Gyr_x_Gyr_z_cov',
#  '98_LAcc_x_Gyr_y_cov',
#  '99_LAcc_z_Gyr_magnitude_cov']

# %%
for key, mi in mutual_informations.items():
    print(key)
    print("="*100)
    with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
        print(pd.Series(data = mi, index = feature_names).sort_values(ascending=False))
    print("-"*100)
    print("")
# Out:
# huawei_hmm_recurrent_diagonal_gaussian_10_10000_random.pickle_validation
# ====================================================================================================
# 11_LAcc_x_hist_0                        1.133813
# 10_LAcc_z_hist_0                        1.132985
# 4_LAcc_y_hist_0                         1.123134
# 27_LAcc_magnitude_hist_9                1.111529
# 1_Acc_magnitude_hist_0                  1.110682
# 2_Acc_magnitude_max_signal1             1.097501
# 13_LAcc_x_max_signal1                   1.089889
# 5_Acc_y_Acc_magnitude_cov               1.087844
# 18_Acc_derotated_z_max_signal2          1.066815
# 25_Gyr_y_hist_0                         1.061401
# 0_LAcc_magnitude_q2                     1.048535
# 9_Acc_magnitude_Acc_derotated_z_cov     1.044770
# 16_Acc_magnitude_LAcc_magnitude_cov     1.042455
# 8_Acc_magnitude_entropy                 1.014231
# 7_Acc_magnitude_hist_9                  1.012460
# 14_Acc_magnitude_Gyr_magnitude_cov      1.008994
# 6_LAcc_y_hist_9                         1.003378
# 32_Gyr_y_max_signal1                    0.999696
# 19_LAcc_z_hist_9                        0.993049
# 58_Gyr_x_hist_0                         0.985206
# 28_Gyr_x_Acc_magnitude_cov              0.982085
# 34_Gyr_y_LAcc_y_cov                     0.980003
# 74_Gyr_x_Acc_derotated_z_cov            0.978100
# 23_LAcc_x_hist_9                        0.972753
# 38_Gyr_x_LAcc_z_cov                     0.962769
# 55_LAcc_z_LAcc_y_cov                    0.956783
# 37_Gyr_y_Acc_magnitude_cov              0.949769
# 31_LAcc_y_Gyr_magnitude_cov             0.948091
# 20_LAcc_y_Acc_magnitude_cov             0.946732
# 3_LAcc_y_q1                             0.945778
# 33_LAcc_z_Acc_y_cov                     0.942460
# 45_Gyr_x_LAcc_x_cov                     0.941773
# 39_Gyr_x_LAcc_y_cov                     0.939585
# 36_LAcc_y_Acc_derotated_z_cov           0.936239
# 60_LAcc_z_Gyr_y_cov                     0.933473
# 41_Acc_derotated_z_hist_9               0.931595
# 49_Acc_z_LAcc_y_cov                     0.930415
# 21_Acc_z_Acc_magnitude_cov              0.923454
# 68_Acc_derotated_y_max_signal2          0.923012
# 63_Gyr_x_Acc_y_cov                      0.922657
# 30_Acc_z_LAcc_z_cov                     0.921824
# 66_Acc_derotated_x_hist_0               0.921642
# 29_LAcc_z_pitch_cov                     0.920810
# 15_Acc_y_LAcc_y_cov                     0.920638
# 83_Acc_z_Gyr_z_cov                      0.916891
# 67_Gyr_z_LAcc_z_cov                     0.913706
# 89_Gra_z_LAcc_y_cov                     0.911085
# 26_LAcc_z_Acc_magnitude_cov             0.910397
# 80_Acc_z_Gyr_x_cov                      0.909857
# 35_LAcc_x_Acc_y_cov                     0.909723
# 98_LAcc_x_Gyr_y_cov                     0.909680
# 52_Acc_x_LAcc_x_cov                     0.907410
# 59_Gyr_z_LAcc_y_cov                     0.904445
# 69_LAcc_y_pitch_cov                     0.902332
# 46_Acc_x_LAcc_y_cov                     0.902207
# 93_LAcc_x_Gyr_magnitude_cov             0.898936
# 81_Acc_x_Gyr_x_cov                      0.898109
# 17_Acc_magnitude_hist_1                 0.891972
# 79_LAcc_x_max                           0.891807
# 72_Acc_y_Gyr_y_cov                      0.890388
# 99_LAcc_z_Gyr_magnitude_cov             0.889429
# 22_Acc_magnitude_Gra_magnitude_cov      0.887794
# 73_LAcc_x_Gra_z_cov                     0.887396
# 54_LAcc_y_max                           0.885085
# 87_Gyr_z_hist_0                         0.884300
# 12_Acc_y_hist_9                         0.884290
# 57_Acc_x_hist_9                         0.882825
# 92_Gyr_magnitude_hist_9                 0.878692
# 43_LAcc_x_LAcc_z_cov                    0.876124
# 40_LAcc_x_Acc_magnitude_cov             0.874127
# 94_Acc_derotated_y_hist_0               0.873004
# 56_Acc_magnitude_pitch_cov              0.868029
# 61_Gyr_z_Acc_magnitude_cov              0.866612
# 42_LAcc_x_LAcc_y_cov                    0.857018
# 90_Acc_z_LAcc_x_cov                     0.856778
# 62_Gyr_z_max_signal3                    0.850559
# 47_LAcc_y_Gra_magnitude_cov             0.850301
# 75_Acc_x_LAcc_z_cov                     0.848611
# 24_Acc_magnitude_hist_2                 0.847158
# 85_LAcc_x_pitch_cov                     0.846481
# 91_Gyr_z_LAcc_x_cov                     0.843748
# 48_Acc_x_Acc_magnitude_cov              0.838127
# 65_Acc_magnitude_Acc_derotated_y_cov    0.830416
# 97_Gyr_x_Gyr_z_cov                      0.826314
# 88_LAcc_x_hist_1                        0.824404
# 51_Acc_magnitude_Acc_derotated_x_cov    0.820582
# 96_LAcc_y_Acc_derotated_x_cov           0.819370
# 64_Acc_y_Acc_derotated_z_cov            0.807986
# 82_Gyr_x_pitch_cov                      0.802563
# 71_Acc_y_LAcc_magnitude_cov             0.783743
# 53_Acc_y_Gra_magnitude_cov              0.760093
# 77_Acc_y_Gyr_magnitude_cov              0.752851
# 44_Gra_y_energy                         0.750860
# 76_LAcc_y_hist_2                        0.745635
# 70_Gra_magnitude_energy                 0.743140
# 84_pitch_max_signal1                    0.722689
# 86_pitch_hist_0                         0.714173
# 95_LAcc_y_Mag_z_cov                     0.635214
# 78_Acc_magnitude_q1                     0.546700
# 50_Acc_y_mean                           0.532488
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_hmm_recurrent_diagonal_gaussian_1000_10000_random.pickle_validation
# ====================================================================================================
# 4_LAcc_y_hist_0                         1.299619
# 1_Acc_magnitude_hist_0                  1.225339
# 5_Acc_y_Acc_magnitude_cov               1.206193
# 10_LAcc_z_hist_0                        1.204595
# 2_Acc_magnitude_max_signal1             1.193775
# 11_LAcc_x_hist_0                        1.180908
# 27_LAcc_magnitude_hist_9                1.176868
# 6_LAcc_y_hist_9                         1.129132
# 0_LAcc_magnitude_q2                     1.124151
# 18_Acc_derotated_z_max_signal2          1.119816
# 13_LAcc_x_max_signal1                   1.116446
# 14_Acc_magnitude_Gyr_magnitude_cov      1.109051
# 16_Acc_magnitude_LAcc_magnitude_cov     1.104670
# 9_Acc_magnitude_Acc_derotated_z_cov     1.103982
# 7_Acc_magnitude_hist_9                  1.095390
# 28_Gyr_x_Acc_magnitude_cov              1.088393
# 8_Acc_magnitude_entropy                 1.087732
# 25_Gyr_y_hist_0                         1.070510
# 3_LAcc_y_q1                             1.045553
# 34_Gyr_y_LAcc_y_cov                     1.036202
# 74_Gyr_x_Acc_derotated_z_cov            1.035228
# 19_LAcc_z_hist_9                        1.029854
# 32_Gyr_y_max_signal1                    1.026490
# 38_Gyr_x_LAcc_z_cov                     1.026472
# 20_LAcc_y_Acc_magnitude_cov             1.018051
# 58_Gyr_x_hist_0                         1.011698
# 39_Gyr_x_LAcc_y_cov                     1.009037
# 49_Acc_z_LAcc_y_cov                     1.008211
# 55_LAcc_z_LAcc_y_cov                    1.007920
# 31_LAcc_y_Gyr_magnitude_cov             1.004487
# 36_LAcc_y_Acc_derotated_z_cov           1.004281
# 63_Gyr_x_Acc_y_cov                      1.000230
# 45_Gyr_x_LAcc_x_cov                     0.995213
# 15_Acc_y_LAcc_y_cov                     0.990376
# 68_Acc_derotated_y_max_signal2          0.988145
# 83_Acc_z_Gyr_z_cov                      0.983997
# 60_LAcc_z_Gyr_y_cov                     0.981955
# 22_Acc_magnitude_Gra_magnitude_cov      0.981565
# 37_Gyr_y_Acc_magnitude_cov              0.981388
# 12_Acc_y_hist_9                         0.979828
# 41_Acc_derotated_z_hist_9               0.978209
# 23_LAcc_x_hist_9                        0.976787
# 66_Acc_derotated_x_hist_0               0.975351
# 33_LAcc_z_Acc_y_cov                     0.973503
# 81_Acc_x_Gyr_x_cov                      0.970570
# 94_Acc_derotated_y_hist_0               0.967945
# 30_Acc_z_LAcc_z_cov                     0.967810
# 17_Acc_magnitude_hist_1                 0.962230
# 59_Gyr_z_LAcc_y_cov                     0.960981
# 54_LAcc_y_max                           0.958073
# 35_LAcc_x_Acc_y_cov                     0.954897
# 21_Acc_z_Acc_magnitude_cov              0.954188
# 67_Gyr_z_LAcc_z_cov                     0.953377
# 80_Acc_z_Gyr_x_cov                      0.952393
# 89_Gra_z_LAcc_y_cov                     0.945958
# 61_Gyr_z_Acc_magnitude_cov              0.942720
# 87_Gyr_z_hist_0                         0.942710
# 26_LAcc_z_Acc_magnitude_cov             0.941657
# 46_Acc_x_LAcc_y_cov                     0.937330
# 93_LAcc_x_Gyr_magnitude_cov             0.936325
# 72_Acc_y_Gyr_y_cov                      0.932416
# 99_LAcc_z_Gyr_magnitude_cov             0.930770
# 79_LAcc_x_max                           0.929557
# 98_LAcc_x_Gyr_y_cov                     0.923529
# 90_Acc_z_LAcc_x_cov                     0.921165
# 43_LAcc_x_LAcc_z_cov                    0.918552
# 42_LAcc_x_LAcc_y_cov                    0.917517
# 52_Acc_x_LAcc_x_cov                     0.915768
# 69_LAcc_y_pitch_cov                     0.912508
# 40_LAcc_x_Acc_magnitude_cov             0.912171
# 92_Gyr_magnitude_hist_9                 0.909866
# 24_Acc_magnitude_hist_2                 0.908944
# 73_LAcc_x_Gra_z_cov                     0.906135
# 29_LAcc_z_pitch_cov                     0.903765
# 57_Acc_x_hist_9                         0.902970
# 47_LAcc_y_Gra_magnitude_cov             0.900769
# 62_Gyr_z_max_signal3                    0.899254
# 91_Gyr_z_LAcc_x_cov                     0.896516
# 48_Acc_x_Acc_magnitude_cov              0.883407
# 56_Acc_magnitude_pitch_cov              0.882748
# 51_Acc_magnitude_Acc_derotated_x_cov    0.882319
# 97_Gyr_x_Gyr_z_cov                      0.877003
# 75_Acc_x_LAcc_z_cov                     0.874254
# 96_LAcc_y_Acc_derotated_x_cov           0.871526
# 65_Acc_magnitude_Acc_derotated_y_cov    0.868684
# 64_Acc_y_Acc_derotated_z_cov            0.868608
# 85_LAcc_x_pitch_cov                     0.855400
# 88_LAcc_x_hist_1                        0.840541
# 76_LAcc_y_hist_2                        0.839905
# 71_Acc_y_LAcc_magnitude_cov             0.824532
# 53_Acc_y_Gra_magnitude_cov              0.811793
# 70_Gra_magnitude_energy                 0.805097
# 77_Acc_y_Gyr_magnitude_cov              0.803521
# 82_Gyr_x_pitch_cov                      0.802354
# 44_Gra_y_energy                         0.762698
# 84_pitch_max_signal1                    0.728393
# 86_pitch_hist_0                         0.727489
# 95_LAcc_y_Mag_z_cov                     0.687458
# 78_Acc_magnitude_q1                     0.558653
# 50_Acc_y_mean                           0.538755
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_hmm_recurrent_diagonal_gaussian_1000_10000_kmeans.pickle_validation
# ====================================================================================================
# 4_LAcc_y_hist_0                         0.994046
# 18_Acc_derotated_z_max_signal2          0.988684
# 8_Acc_magnitude_entropy                 0.973120
# 10_LAcc_z_hist_0                        0.971029
# 1_Acc_magnitude_hist_0                  0.969175
# 9_Acc_magnitude_Acc_derotated_z_cov     0.966532
# 25_Gyr_y_hist_0                         0.961320
# 2_Acc_magnitude_max_signal1             0.957719
# 11_LAcc_x_hist_0                        0.954825
# 27_LAcc_magnitude_hist_9                0.954288
# 5_Acc_y_Acc_magnitude_cov               0.945504
# 58_Gyr_x_hist_0                         0.928788
# 32_Gyr_y_max_signal1                    0.923148
# 13_LAcc_x_max_signal1                   0.915280
# 6_LAcc_y_hist_9                         0.895371
# 28_Gyr_x_Acc_magnitude_cov              0.895278
# 7_Acc_magnitude_hist_9                  0.891317
# 69_LAcc_y_pitch_cov                     0.890182
# 41_Acc_derotated_z_hist_9               0.889817
# 14_Acc_magnitude_Gyr_magnitude_cov      0.886451
# 21_Acc_z_Acc_magnitude_cov              0.880875
# 74_Gyr_x_Acc_derotated_z_cov            0.880693
# 29_LAcc_z_pitch_cov                     0.878489
# 55_LAcc_z_LAcc_y_cov                    0.876767
# 0_LAcc_magnitude_q2                     0.866896
# 56_Acc_magnitude_pitch_cov              0.866625
# 19_LAcc_z_hist_9                        0.862171
# 16_Acc_magnitude_LAcc_magnitude_cov     0.860358
# 36_LAcc_y_Acc_derotated_z_cov           0.858024
# 89_Gra_z_LAcc_y_cov                     0.854990
# 49_Acc_z_LAcc_y_cov                     0.847061
# 38_Gyr_x_LAcc_z_cov                     0.844832
# 85_LAcc_x_pitch_cov                     0.841082
# 68_Acc_derotated_y_max_signal2          0.840632
# 39_Gyr_x_LAcc_y_cov                     0.837425
# 20_LAcc_y_Acc_magnitude_cov             0.836842
# 54_LAcc_y_max                           0.835551
# 31_LAcc_y_Gyr_magnitude_cov             0.835349
# 63_Gyr_x_Acc_y_cov                      0.831850
# 79_LAcc_x_max                           0.831167
# 34_Gyr_y_LAcc_y_cov                     0.830648
# 37_Gyr_y_Acc_magnitude_cov              0.830126
# 80_Acc_z_Gyr_x_cov                      0.825654
# 84_pitch_max_signal1                    0.820969
# 30_Acc_z_LAcc_z_cov                     0.820224
# 3_LAcc_y_q1                             0.818127
# 23_LAcc_x_hist_9                        0.817736
# 17_Acc_magnitude_hist_1                 0.817440
# 61_Gyr_z_Acc_magnitude_cov              0.817049
# 67_Gyr_z_LAcc_z_cov                     0.816838
# 82_Gyr_x_pitch_cov                      0.811086
# 66_Acc_derotated_x_hist_0               0.808620
# 22_Acc_magnitude_Gra_magnitude_cov      0.805105
# 87_Gyr_z_hist_0                         0.804555
# 86_pitch_hist_0                         0.804196
# 40_LAcc_x_Acc_magnitude_cov             0.802782
# 43_LAcc_x_LAcc_z_cov                    0.800316
# 33_LAcc_z_Acc_y_cov                     0.799837
# 94_Acc_derotated_y_hist_0               0.798797
# 35_LAcc_x_Acc_y_cov                     0.798435
# 65_Acc_magnitude_Acc_derotated_y_cov    0.798186
# 45_Gyr_x_LAcc_x_cov                     0.797035
# 59_Gyr_z_LAcc_y_cov                     0.796341
# 15_Acc_y_LAcc_y_cov                     0.796076
# 60_LAcc_z_Gyr_y_cov                     0.795912
# 81_Acc_x_Gyr_x_cov                      0.795582
# 92_Gyr_magnitude_hist_9                 0.795414
# 42_LAcc_x_LAcc_y_cov                    0.792759
# 48_Acc_x_Acc_magnitude_cov              0.792004
# 73_LAcc_x_Gra_z_cov                     0.791315
# 90_Acc_z_LAcc_x_cov                     0.790317
# 98_LAcc_x_Gyr_y_cov                     0.789514
# 26_LAcc_z_Acc_magnitude_cov             0.788395
# 72_Acc_y_Gyr_y_cov                      0.788233
# 62_Gyr_z_max_signal3                    0.787805
# 12_Acc_y_hist_9                         0.783939
# 83_Acc_z_Gyr_z_cov                      0.783047
# 99_LAcc_z_Gyr_magnitude_cov             0.779945
# 51_Acc_magnitude_Acc_derotated_x_cov    0.779701
# 93_LAcc_x_Gyr_magnitude_cov             0.779186
# 24_Acc_magnitude_hist_2                 0.771484
# 47_LAcc_y_Gra_magnitude_cov             0.764016
# 46_Acc_x_LAcc_y_cov                     0.756036
# 91_Gyr_z_LAcc_x_cov                     0.749199
# 97_Gyr_x_Gyr_z_cov                      0.748755
# 52_Acc_x_LAcc_x_cov                     0.746810
# 44_Gra_y_energy                         0.735928
# 64_Acc_y_Acc_derotated_z_cov            0.731304
# 75_Acc_x_LAcc_z_cov                     0.728296
# 57_Acc_x_hist_9                         0.727260
# 96_LAcc_y_Acc_derotated_x_cov           0.719088
# 53_Acc_y_Gra_magnitude_cov              0.695148
# 88_LAcc_x_hist_1                        0.684005
# 76_LAcc_y_hist_2                        0.676895
# 70_Gra_magnitude_energy                 0.675270
# 71_Acc_y_LAcc_magnitude_cov             0.666145
# 77_Acc_y_Gyr_magnitude_cov              0.663064
# 95_LAcc_y_Mag_z_cov                     0.556290
# 78_Acc_magnitude_q1                     0.552753
# 50_Acc_y_mean                           0.480331
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_hmm_recurrent_diagonal_gaussian_10000_10000_random.pickle_validation
# ====================================================================================================
# 4_LAcc_y_hist_0                         1.173487
# 10_LAcc_z_hist_0                        1.137469
# 11_LAcc_x_hist_0                        1.126160
# 27_LAcc_magnitude_hist_9                1.098023
# 1_Acc_magnitude_hist_0                  1.095942
# 5_Acc_y_Acc_magnitude_cov               1.078689
# 2_Acc_magnitude_max_signal1             1.071024
# 13_LAcc_x_max_signal1                   1.066866
# 8_Acc_magnitude_entropy                 1.060854
# 25_Gyr_y_hist_0                         1.054566
# 0_LAcc_magnitude_q2                     1.032949
# 6_LAcc_y_hist_9                         1.019567
# 9_Acc_magnitude_Acc_derotated_z_cov     1.015210
# 16_Acc_magnitude_LAcc_magnitude_cov     1.010096
# 14_Acc_magnitude_Gyr_magnitude_cov      1.006774
# 18_Acc_derotated_z_max_signal2          1.001611
# 32_Gyr_y_max_signal1                    0.999082
# 7_Acc_magnitude_hist_9                  0.990849
# 19_LAcc_z_hist_9                        0.987383
# 28_Gyr_x_Acc_magnitude_cov              0.985511
# 55_LAcc_z_LAcc_y_cov                    0.969845
# 39_Gyr_x_LAcc_y_cov                     0.969674
# 34_Gyr_y_LAcc_y_cov                     0.968250
# 58_Gyr_x_hist_0                         0.959656
# 38_Gyr_x_LAcc_z_cov                     0.957065
# 74_Gyr_x_Acc_derotated_z_cov            0.954666
# 45_Gyr_x_LAcc_x_cov                     0.954447
# 37_Gyr_y_Acc_magnitude_cov              0.944311
# 20_LAcc_y_Acc_magnitude_cov             0.943733
# 3_LAcc_y_q1                             0.943050
# 23_LAcc_x_hist_9                        0.940980
# 49_Acc_z_LAcc_y_cov                     0.938711
# 30_Acc_z_LAcc_z_cov                     0.935150
# 33_LAcc_z_Acc_y_cov                     0.934774
# 83_Acc_z_Gyr_z_cov                      0.929481
# 60_LAcc_z_Gyr_y_cov                     0.925514
# 68_Acc_derotated_y_max_signal2          0.924177
# 26_LAcc_z_Acc_magnitude_cov             0.922651
# 54_LAcc_y_max                           0.919620
# 98_LAcc_x_Gyr_y_cov                     0.915292
# 66_Acc_derotated_x_hist_0               0.913151
# 63_Gyr_x_Acc_y_cov                      0.912813
# 67_Gyr_z_LAcc_z_cov                     0.912286
# 99_LAcc_z_Gyr_magnitude_cov             0.910795
# 31_LAcc_y_Gyr_magnitude_cov             0.910018
# 36_LAcc_y_Acc_derotated_z_cov           0.908804
# 81_Acc_x_Gyr_x_cov                      0.907738
# 59_Gyr_z_LAcc_y_cov                     0.907458
# 15_Acc_y_LAcc_y_cov                     0.905126
# 21_Acc_z_Acc_magnitude_cov              0.902355
# 89_Gra_z_LAcc_y_cov                     0.896402
# 79_LAcc_x_max                           0.894503
# 52_Acc_x_LAcc_x_cov                     0.892168
# 94_Acc_derotated_y_hist_0               0.890604
# 35_LAcc_x_Acc_y_cov                     0.890203
# 80_Acc_z_Gyr_x_cov                      0.887244
# 29_LAcc_z_pitch_cov                     0.885564
# 61_Gyr_z_Acc_magnitude_cov              0.884165
# 40_LAcc_x_Acc_magnitude_cov             0.883918
# 90_Acc_z_LAcc_x_cov                     0.883896
# 17_Acc_magnitude_hist_1                 0.881568
# 57_Acc_x_hist_9                         0.879322
# 72_Acc_y_Gyr_y_cov                      0.879200
# 46_Acc_x_LAcc_y_cov                     0.877950
# 22_Acc_magnitude_Gra_magnitude_cov      0.877716
# 41_Acc_derotated_z_hist_9               0.872456
# 87_Gyr_z_hist_0                         0.871766
# 75_Acc_x_LAcc_z_cov                     0.868035
# 93_LAcc_x_Gyr_magnitude_cov             0.866654
# 12_Acc_y_hist_9                         0.863155
# 69_LAcc_y_pitch_cov                     0.862350
# 43_LAcc_x_LAcc_z_cov                    0.861518
# 73_LAcc_x_Gra_z_cov                     0.860880
# 92_Gyr_magnitude_hist_9                 0.848089
# 42_LAcc_x_LAcc_y_cov                    0.847808
# 91_Gyr_z_LAcc_x_cov                     0.844629
# 24_Acc_magnitude_hist_2                 0.843429
# 62_Gyr_z_max_signal3                    0.837034
# 47_LAcc_y_Gra_magnitude_cov             0.834874
# 51_Acc_magnitude_Acc_derotated_x_cov    0.830089
# 65_Acc_magnitude_Acc_derotated_y_cov    0.826588
# 48_Acc_x_Acc_magnitude_cov              0.822958
# 96_LAcc_y_Acc_derotated_x_cov           0.821948
# 56_Acc_magnitude_pitch_cov              0.811944
# 85_LAcc_x_pitch_cov                     0.810436
# 88_LAcc_x_hist_1                        0.800175
# 97_Gyr_x_Gyr_z_cov                      0.798636
# 64_Acc_y_Acc_derotated_z_cov            0.785173
# 82_Gyr_x_pitch_cov                      0.770720
# 76_LAcc_y_hist_2                        0.765046
# 71_Acc_y_LAcc_magnitude_cov             0.742907
# 44_Gra_y_energy                         0.740293
# 70_Gra_magnitude_energy                 0.737202
# 53_Acc_y_Gra_magnitude_cov              0.725435
# 77_Acc_y_Gyr_magnitude_cov              0.719416
# 84_pitch_max_signal1                    0.702837
# 86_pitch_hist_0                         0.689852
# 95_LAcc_y_Mag_z_cov                     0.633845
# 78_Acc_magnitude_q1                     0.528819
# 50_Acc_y_mean                           0.513836
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_hmm_recurrent_diagonal_gaussian_10000_10000_kmeans.pickle_validation
# ====================================================================================================
# 4_LAcc_y_hist_0                         0.993513
# 18_Acc_derotated_z_max_signal2          0.990335
# 8_Acc_magnitude_entropy                 0.972202
# 10_LAcc_z_hist_0                        0.971786
# 1_Acc_magnitude_hist_0                  0.970527
# 9_Acc_magnitude_Acc_derotated_z_cov     0.966940
# 25_Gyr_y_hist_0                         0.961463
# 2_Acc_magnitude_max_signal1             0.957775
# 11_LAcc_x_hist_0                        0.955150
# 27_LAcc_magnitude_hist_9                0.952206
# 5_Acc_y_Acc_magnitude_cov               0.948707
# 58_Gyr_x_hist_0                         0.929069
# 32_Gyr_y_max_signal1                    0.924685
# 13_LAcc_x_max_signal1                   0.915038
# 28_Gyr_x_Acc_magnitude_cov              0.897924
# 6_LAcc_y_hist_9                         0.897589
# 7_Acc_magnitude_hist_9                  0.890816
# 41_Acc_derotated_z_hist_9               0.890300
# 69_LAcc_y_pitch_cov                     0.887995
# 14_Acc_magnitude_Gyr_magnitude_cov      0.886592
# 74_Gyr_x_Acc_derotated_z_cov            0.881695
# 21_Acc_z_Acc_magnitude_cov              0.879799
# 55_LAcc_z_LAcc_y_cov                    0.877907
# 29_LAcc_z_pitch_cov                     0.876772
# 56_Acc_magnitude_pitch_cov              0.866330
# 0_LAcc_magnitude_q2                     0.865651
# 19_LAcc_z_hist_9                        0.860721
# 16_Acc_magnitude_LAcc_magnitude_cov     0.859384
# 36_LAcc_y_Acc_derotated_z_cov           0.857720
# 89_Gra_z_LAcc_y_cov                     0.855599
# 49_Acc_z_LAcc_y_cov                     0.847488
# 38_Gyr_x_LAcc_z_cov                     0.846391
# 68_Acc_derotated_y_max_signal2          0.839426
# 85_LAcc_x_pitch_cov                     0.839290
# 39_Gyr_x_LAcc_y_cov                     0.837330
# 20_LAcc_y_Acc_magnitude_cov             0.836708
# 31_LAcc_y_Gyr_magnitude_cov             0.836364
# 54_LAcc_y_max                           0.834941
# 63_Gyr_x_Acc_y_cov                      0.832753
# 34_Gyr_y_LAcc_y_cov                     0.831575
# 79_LAcc_x_max                           0.831208
# 37_Gyr_y_Acc_magnitude_cov              0.830948
# 80_Acc_z_Gyr_x_cov                      0.828447
# 30_Acc_z_LAcc_z_cov                     0.821594
# 84_pitch_max_signal1                    0.819577
# 23_LAcc_x_hist_9                        0.818281
# 3_LAcc_y_q1                             0.817892
# 61_Gyr_z_Acc_magnitude_cov              0.817560
# 67_Gyr_z_LAcc_z_cov                     0.817013
# 17_Acc_magnitude_hist_1                 0.816653
# 82_Gyr_x_pitch_cov                      0.811488
# 66_Acc_derotated_x_hist_0               0.808173
# 22_Acc_magnitude_Gra_magnitude_cov      0.806101
# 86_pitch_hist_0                         0.803534
# 87_Gyr_z_hist_0                         0.803112
# 40_LAcc_x_Acc_magnitude_cov             0.802138
# 33_LAcc_z_Acc_y_cov                     0.800530
# 94_Acc_derotated_y_hist_0               0.798575
# 35_LAcc_x_Acc_y_cov                     0.798150
# 45_Gyr_x_LAcc_x_cov                     0.798059
# 43_LAcc_x_LAcc_z_cov                    0.797971
# 60_LAcc_z_Gyr_y_cov                     0.797610
# 59_Gyr_z_LAcc_y_cov                     0.797030
# 15_Acc_y_LAcc_y_cov                     0.796823
# 65_Acc_magnitude_Acc_derotated_y_cov    0.796081
# 81_Acc_x_Gyr_x_cov                      0.795992
# 92_Gyr_magnitude_hist_9                 0.795959
# 42_LAcc_x_LAcc_y_cov                    0.792255
# 48_Acc_x_Acc_magnitude_cov              0.791702
# 73_LAcc_x_Gra_z_cov                     0.791612
# 98_LAcc_x_Gyr_y_cov                     0.790628
# 72_Acc_y_Gyr_y_cov                      0.790159
# 90_Acc_z_LAcc_x_cov                     0.789962
# 26_LAcc_z_Acc_magnitude_cov             0.788183
# 62_Gyr_z_max_signal3                    0.787544
# 83_Acc_z_Gyr_z_cov                      0.784749
# 12_Acc_y_hist_9                         0.781479
# 99_LAcc_z_Gyr_magnitude_cov             0.779779
# 51_Acc_magnitude_Acc_derotated_x_cov    0.779428
# 93_LAcc_x_Gyr_magnitude_cov             0.779029
# 24_Acc_magnitude_hist_2                 0.770441
# 47_LAcc_y_Gra_magnitude_cov             0.768092
# 46_Acc_x_LAcc_y_cov                     0.754639
# 91_Gyr_z_LAcc_x_cov                     0.749029
# 97_Gyr_x_Gyr_z_cov                      0.748571
# 52_Acc_x_LAcc_x_cov                     0.746743
# 44_Gra_y_energy                         0.734135
# 64_Acc_y_Acc_derotated_z_cov            0.731177
# 75_Acc_x_LAcc_z_cov                     0.728905
# 57_Acc_x_hist_9                         0.727759
# 96_LAcc_y_Acc_derotated_x_cov           0.718564
# 53_Acc_y_Gra_magnitude_cov              0.691797
# 88_LAcc_x_hist_1                        0.683081
# 76_LAcc_y_hist_2                        0.677101
# 70_Gra_magnitude_energy                 0.676486
# 71_Acc_y_LAcc_magnitude_cov             0.664171
# 77_Acc_y_Gyr_magnitude_cov              0.662060
# 78_Acc_magnitude_q1                     0.553981
# 95_LAcc_y_Mag_z_cov                     0.553410
# 50_Acc_y_mean                           0.479705
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_hmm_recurrent_diagonal_gaussian_100000_10000_random.pickle_validation
# ====================================================================================================
# 4_LAcc_y_hist_0                         1.250554
# 1_Acc_magnitude_hist_0                  1.183459
# 5_Acc_y_Acc_magnitude_cov               1.165658
# 2_Acc_magnitude_max_signal1             1.158872
# 10_LAcc_z_hist_0                        1.157268
# 27_LAcc_magnitude_hist_9                1.131692
# 11_LAcc_x_hist_0                        1.128780
# 6_LAcc_y_hist_9                         1.095687
# 0_LAcc_magnitude_q2                     1.094126
# 18_Acc_derotated_z_max_signal2          1.092404
# 14_Acc_magnitude_Gyr_magnitude_cov      1.079968
# 9_Acc_magnitude_Acc_derotated_z_cov     1.079117
# 13_LAcc_x_max_signal1                   1.075674
# 7_Acc_magnitude_hist_9                  1.071558
# 16_Acc_magnitude_LAcc_magnitude_cov     1.056426
# 25_Gyr_y_hist_0                         1.056081
# 28_Gyr_x_Acc_magnitude_cov              1.044663
# 8_Acc_magnitude_entropy                 1.041284
# 3_LAcc_y_q1                             1.026433
# 58_Gyr_x_hist_0                         1.020737
# 32_Gyr_y_max_signal1                    1.004167
# 31_LAcc_y_Gyr_magnitude_cov             0.996093
# 34_Gyr_y_LAcc_y_cov                     0.995709
# 38_Gyr_x_LAcc_z_cov                     0.991319
# 74_Gyr_x_Acc_derotated_z_cov            0.991023
# 19_LAcc_z_hist_9                        0.989681
# 20_LAcc_y_Acc_magnitude_cov             0.986155
# 63_Gyr_x_Acc_y_cov                      0.981373
# 39_Gyr_x_LAcc_y_cov                     0.977974
# 41_Acc_derotated_z_hist_9               0.973698
# 55_LAcc_z_LAcc_y_cov                    0.969369
# 49_Acc_z_LAcc_y_cov                     0.965858
# 23_LAcc_x_hist_9                        0.965653
# 68_Acc_derotated_y_max_signal2          0.962493
# 36_LAcc_y_Acc_derotated_z_cov           0.960974
# 15_Acc_y_LAcc_y_cov                     0.958184
# 21_Acc_z_Acc_magnitude_cov              0.955337
# 12_Acc_y_hist_9                         0.953846
# 45_Gyr_x_LAcc_x_cov                     0.948950
# 22_Acc_magnitude_Gra_magnitude_cov      0.945522
# 37_Gyr_y_Acc_magnitude_cov              0.944133
# 66_Acc_derotated_x_hist_0               0.942561
# 83_Acc_z_Gyr_z_cov                      0.939244
# 59_Gyr_z_LAcc_y_cov                     0.938989
# 17_Acc_magnitude_hist_1                 0.938823
# 33_LAcc_z_Acc_y_cov                     0.938816
# 60_LAcc_z_Gyr_y_cov                     0.935323
# 67_Gyr_z_LAcc_z_cov                     0.934258
# 35_LAcc_x_Acc_y_cov                     0.932718
# 26_LAcc_z_Acc_magnitude_cov             0.932524
# 89_Gra_z_LAcc_y_cov                     0.931043
# 81_Acc_x_Gyr_x_cov                      0.930445
# 30_Acc_z_LAcc_z_cov                     0.930351
# 54_LAcc_y_max                           0.929209
# 29_LAcc_z_pitch_cov                     0.928552
# 94_Acc_derotated_y_hist_0               0.925664
# 46_Acc_x_LAcc_y_cov                     0.915123
# 69_LAcc_y_pitch_cov                     0.911708
# 99_LAcc_z_Gyr_magnitude_cov             0.911191
# 98_LAcc_x_Gyr_y_cov                     0.909562
# 80_Acc_z_Gyr_x_cov                      0.908887
# 93_LAcc_x_Gyr_magnitude_cov             0.908502
# 92_Gyr_magnitude_hist_9                 0.908488
# 72_Acc_y_Gyr_y_cov                      0.903443
# 61_Gyr_z_Acc_magnitude_cov              0.902907
# 87_Gyr_z_hist_0                         0.900738
# 56_Acc_magnitude_pitch_cov              0.898097
# 62_Gyr_z_max_signal3                    0.897734
# 24_Acc_magnitude_hist_2                 0.892733
# 42_LAcc_x_LAcc_y_cov                    0.892725
# 79_LAcc_x_max                           0.891554
# 73_LAcc_x_Gra_z_cov                     0.887476
# 40_LAcc_x_Acc_magnitude_cov             0.887229
# 43_LAcc_x_LAcc_z_cov                    0.880912
# 57_Acc_x_hist_9                         0.876025
# 52_Acc_x_LAcc_x_cov                     0.875353
# 90_Acc_z_LAcc_x_cov                     0.875350
# 47_LAcc_y_Gra_magnitude_cov             0.874946
# 91_Gyr_z_LAcc_x_cov                     0.864068
# 85_LAcc_x_pitch_cov                     0.861193
# 51_Acc_magnitude_Acc_derotated_x_cov    0.859007
# 97_Gyr_x_Gyr_z_cov                      0.851246
# 96_LAcc_y_Acc_derotated_x_cov           0.850680
# 75_Acc_x_LAcc_z_cov                     0.840986
# 48_Acc_x_Acc_magnitude_cov              0.837451
# 64_Acc_y_Acc_derotated_z_cov            0.835014
# 65_Acc_magnitude_Acc_derotated_y_cov    0.826261
# 76_LAcc_y_hist_2                        0.823930
# 88_LAcc_x_hist_1                        0.822222
# 82_Gyr_x_pitch_cov                      0.817466
# 71_Acc_y_LAcc_magnitude_cov             0.806033
# 53_Acc_y_Gra_magnitude_cov              0.801391
# 70_Gra_magnitude_energy                 0.793374
# 77_Acc_y_Gyr_magnitude_cov              0.787822
# 84_pitch_max_signal1                    0.778949
# 86_pitch_hist_0                         0.771123
# 44_Gra_y_energy                         0.767753
# 95_LAcc_y_Mag_z_cov                     0.675444
# 78_Acc_magnitude_q1                     0.570739
# 50_Acc_y_mean                           0.566599
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_hmm_standard_diagonal_gaussian_10000_10000_random.pickle_validation
# ====================================================================================================
# 4_LAcc_y_hist_0                         1.299391
# 1_Acc_magnitude_hist_0                  1.245933
# 2_Acc_magnitude_max_signal1             1.229179
# 10_LAcc_z_hist_0                        1.191692
# 5_Acc_y_Acc_magnitude_cov               1.170848
# 11_LAcc_x_hist_0                        1.154904
# 27_LAcc_magnitude_hist_9                1.149004
# 6_LAcc_y_hist_9                         1.141242
# 7_Acc_magnitude_hist_9                  1.131907
# 0_LAcc_magnitude_q2                     1.129726
# 18_Acc_derotated_z_max_signal2          1.111710
# 9_Acc_magnitude_Acc_derotated_z_cov     1.107240
# 13_LAcc_x_max_signal1                   1.101875
# 8_Acc_magnitude_entropy                 1.084957
# 14_Acc_magnitude_Gyr_magnitude_cov      1.082443
# 25_Gyr_y_hist_0                         1.081731
# 16_Acc_magnitude_LAcc_magnitude_cov     1.065308
# 3_LAcc_y_q1                             1.061553
# 58_Gyr_x_hist_0                         1.053000
# 28_Gyr_x_Acc_magnitude_cov              1.046926
# 32_Gyr_y_max_signal1                    1.032308
# 19_LAcc_z_hist_9                        1.028921
# 31_LAcc_y_Gyr_magnitude_cov             1.008968
# 20_LAcc_y_Acc_magnitude_cov             1.008436
# 74_Gyr_x_Acc_derotated_z_cov            1.005263
# 34_Gyr_y_LAcc_y_cov                     1.003570
# 63_Gyr_x_Acc_y_cov                      1.000482
# 41_Acc_derotated_z_hist_9               0.998240
# 17_Acc_magnitude_hist_1                 0.998002
# 38_Gyr_x_LAcc_z_cov                     0.992063
# 39_Gyr_x_LAcc_y_cov                     0.991416
# 55_LAcc_z_LAcc_y_cov                    0.990939
# 21_Acc_z_Acc_magnitude_cov              0.989033
# 12_Acc_y_hist_9                         0.988217
# 36_LAcc_y_Acc_derotated_z_cov           0.982190
# 49_Acc_z_LAcc_y_cov                     0.978883
# 23_LAcc_x_hist_9                        0.978830
# 15_Acc_y_LAcc_y_cov                     0.978137
# 68_Acc_derotated_y_max_signal2          0.971870
# 29_LAcc_z_pitch_cov                     0.965079
# 69_LAcc_y_pitch_cov                     0.963510
# 66_Acc_derotated_x_hist_0               0.961442
# 89_Gra_z_LAcc_y_cov                     0.961295
# 83_Acc_z_Gyr_z_cov                      0.957402
# 45_Gyr_x_LAcc_x_cov                     0.954926
# 81_Acc_x_Gyr_x_cov                      0.953349
# 33_LAcc_z_Acc_y_cov                     0.951222
# 37_Gyr_y_Acc_magnitude_cov              0.949345
# 92_Gyr_magnitude_hist_9                 0.948257
# 94_Acc_derotated_y_hist_0               0.943448
# 22_Acc_magnitude_Gra_magnitude_cov      0.942578
# 26_LAcc_z_Acc_magnitude_cov             0.940523
# 24_Acc_magnitude_hist_2                 0.939950
# 35_LAcc_x_Acc_y_cov                     0.938633
# 30_Acc_z_LAcc_z_cov                     0.938580
# 60_LAcc_z_Gyr_y_cov                     0.937155
# 67_Gyr_z_LAcc_z_cov                     0.936922
# 59_Gyr_z_LAcc_y_cov                     0.936764
# 87_Gyr_z_hist_0                         0.935984
# 56_Acc_magnitude_pitch_cov              0.933593
# 54_LAcc_y_max                           0.933230
# 93_LAcc_x_Gyr_magnitude_cov             0.926255
# 61_Gyr_z_Acc_magnitude_cov              0.921150
# 62_Gyr_z_max_signal3                    0.920145
# 99_LAcc_z_Gyr_magnitude_cov             0.917969
# 46_Acc_x_LAcc_y_cov                     0.916079
# 40_LAcc_x_Acc_magnitude_cov             0.914816
# 72_Acc_y_Gyr_y_cov                      0.913379
# 73_LAcc_x_Gra_z_cov                     0.911669
# 80_Acc_z_Gyr_x_cov                      0.911155
# 85_LAcc_x_pitch_cov                     0.906700
# 47_LAcc_y_Gra_magnitude_cov             0.904312
# 52_Acc_x_LAcc_x_cov                     0.903833
# 79_LAcc_x_max                           0.900117
# 98_LAcc_x_Gyr_y_cov                     0.898417
# 57_Acc_x_hist_9                         0.897387
# 43_LAcc_x_LAcc_z_cov                    0.892118
# 42_LAcc_x_LAcc_y_cov                    0.889098
# 90_Acc_z_LAcc_x_cov                     0.885930
# 51_Acc_magnitude_Acc_derotated_x_cov    0.885836
# 91_Gyr_z_LAcc_x_cov                     0.881113
# 97_Gyr_x_Gyr_z_cov                      0.871241
# 96_LAcc_y_Acc_derotated_x_cov           0.869531
# 76_LAcc_y_hist_2                        0.864019
# 48_Acc_x_Acc_magnitude_cov              0.861169
# 64_Acc_y_Acc_derotated_z_cov            0.855618
# 82_Gyr_x_pitch_cov                      0.850265
# 65_Acc_magnitude_Acc_derotated_y_cov    0.845098
# 75_Acc_x_LAcc_z_cov                     0.845027
# 88_LAcc_x_hist_1                        0.832849
# 70_Gra_magnitude_energy                 0.827552
# 53_Acc_y_Gra_magnitude_cov              0.824976
# 86_pitch_hist_0                         0.820969
# 71_Acc_y_LAcc_magnitude_cov             0.820693
# 84_pitch_max_signal1                    0.817760
# 44_Gra_y_energy                         0.806336
# 77_Acc_y_Gyr_magnitude_cov              0.801697
# 95_LAcc_y_Mag_z_cov                     0.686419
# 78_Acc_magnitude_q1                     0.592126
# 50_Acc_y_mean                           0.584821
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_hmm_standard_diagonal_gaussian_10000_10000_kmeans.pickle_validation
# ====================================================================================================
# 4_LAcc_y_hist_0                         0.992504
# 18_Acc_derotated_z_max_signal2          0.989985
# 8_Acc_magnitude_entropy                 0.972105
# 10_LAcc_z_hist_0                        0.970005
# 1_Acc_magnitude_hist_0                  0.969528
# 9_Acc_magnitude_Acc_derotated_z_cov     0.965802
# 25_Gyr_y_hist_0                         0.960724
# 2_Acc_magnitude_max_signal1             0.957646
# 11_LAcc_x_hist_0                        0.953901
# 27_LAcc_magnitude_hist_9                0.952789
# 5_Acc_y_Acc_magnitude_cov               0.948314
# 58_Gyr_x_hist_0                         0.929329
# 32_Gyr_y_max_signal1                    0.923836
# 13_LAcc_x_max_signal1                   0.914634
# 28_Gyr_x_Acc_magnitude_cov              0.898320
# 6_LAcc_y_hist_9                         0.896521
# 7_Acc_magnitude_hist_9                  0.891986
# 41_Acc_derotated_z_hist_9               0.890514
# 69_LAcc_y_pitch_cov                     0.888307
# 14_Acc_magnitude_Gyr_magnitude_cov      0.887779
# 74_Gyr_x_Acc_derotated_z_cov            0.883166
# 21_Acc_z_Acc_magnitude_cov              0.880570
# 55_LAcc_z_LAcc_y_cov                    0.879460
# 29_LAcc_z_pitch_cov                     0.877156
# 56_Acc_magnitude_pitch_cov              0.867250
# 0_LAcc_magnitude_q2                     0.864014
# 19_LAcc_z_hist_9                        0.859919
# 16_Acc_magnitude_LAcc_magnitude_cov     0.858342
# 36_LAcc_y_Acc_derotated_z_cov           0.857352
# 89_Gra_z_LAcc_y_cov                     0.855864
# 38_Gyr_x_LAcc_z_cov                     0.846241
# 49_Acc_z_LAcc_y_cov                     0.845150
# 85_LAcc_x_pitch_cov                     0.840273
# 68_Acc_derotated_y_max_signal2          0.839176
# 39_Gyr_x_LAcc_y_cov                     0.838766
# 31_LAcc_y_Gyr_magnitude_cov             0.837535
# 54_LAcc_y_max                           0.835251
# 20_LAcc_y_Acc_magnitude_cov             0.835034
# 63_Gyr_x_Acc_y_cov                      0.834174
# 34_Gyr_y_LAcc_y_cov                     0.831632
# 79_LAcc_x_max                           0.831506
# 37_Gyr_y_Acc_magnitude_cov              0.830474
# 80_Acc_z_Gyr_x_cov                      0.828557
# 30_Acc_z_LAcc_z_cov                     0.821635
# 84_pitch_max_signal1                    0.818550
# 23_LAcc_x_hist_9                        0.817442
# 67_Gyr_z_LAcc_z_cov                     0.817358
# 61_Gyr_z_Acc_magnitude_cov              0.817186
# 3_LAcc_y_q1                             0.817149
# 17_Acc_magnitude_hist_1                 0.814553
# 82_Gyr_x_pitch_cov                      0.812440
# 22_Acc_magnitude_Gra_magnitude_cov      0.807730
# 66_Acc_derotated_x_hist_0               0.807505
# 87_Gyr_z_hist_0                         0.803786
# 86_pitch_hist_0                         0.802889
# 40_LAcc_x_Acc_magnitude_cov             0.801656
# 33_LAcc_z_Acc_y_cov                     0.799904
# 94_Acc_derotated_y_hist_0               0.799085
# 45_Gyr_x_LAcc_x_cov                     0.798835
# 35_LAcc_x_Acc_y_cov                     0.798391
# 43_LAcc_x_LAcc_z_cov                    0.798340
# 81_Acc_x_Gyr_x_cov                      0.797333
# 60_LAcc_z_Gyr_y_cov                     0.796955
# 15_Acc_y_LAcc_y_cov                     0.796817
# 59_Gyr_z_LAcc_y_cov                     0.796798
# 65_Acc_magnitude_Acc_derotated_y_cov    0.796300
# 92_Gyr_magnitude_hist_9                 0.796074
# 73_LAcc_x_Gra_z_cov                     0.792178
# 42_LAcc_x_LAcc_y_cov                    0.791644
# 48_Acc_x_Acc_magnitude_cov              0.791285
# 90_Acc_z_LAcc_x_cov                     0.791267
# 72_Acc_y_Gyr_y_cov                      0.790908
# 98_LAcc_x_Gyr_y_cov                     0.790749
# 62_Gyr_z_max_signal3                    0.788901
# 26_LAcc_z_Acc_magnitude_cov             0.787676
# 83_Acc_z_Gyr_z_cov                      0.783844
# 12_Acc_y_hist_9                         0.781168
# 51_Acc_magnitude_Acc_derotated_x_cov    0.780379
# 99_LAcc_z_Gyr_magnitude_cov             0.779482
# 93_LAcc_x_Gyr_magnitude_cov             0.778689
# 24_Acc_magnitude_hist_2                 0.770215
# 47_LAcc_y_Gra_magnitude_cov             0.767252
# 46_Acc_x_LAcc_y_cov                     0.756789
# 91_Gyr_z_LAcc_x_cov                     0.749939
# 97_Gyr_x_Gyr_z_cov                      0.749101
# 52_Acc_x_LAcc_x_cov                     0.745685
# 44_Gra_y_energy                         0.733603
# 64_Acc_y_Acc_derotated_z_cov            0.731399
# 75_Acc_x_LAcc_z_cov                     0.728781
# 57_Acc_x_hist_9                         0.727730
# 96_LAcc_y_Acc_derotated_x_cov           0.717997
# 53_Acc_y_Gra_magnitude_cov              0.693569
# 88_LAcc_x_hist_1                        0.686098
# 76_LAcc_y_hist_2                        0.680011
# 70_Gra_magnitude_energy                 0.675292
# 71_Acc_y_LAcc_magnitude_cov             0.664754
# 77_Acc_y_Gyr_magnitude_cov              0.663732
# 95_LAcc_y_Mag_z_cov                     0.554539
# 78_Acc_magnitude_q1                     0.553644
# 50_Acc_y_mean                           0.479061
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_reduced_hmm_recurrent_diagonal_gaussian_10000_10000_random.pickle_validation
# ====================================================================================================
# 1_Acc_magnitude_hist_0                  1.370378
# 2_Acc_magnitude_max_signal1             1.359527
# 10_LAcc_z_hist_0                        1.305029
# 4_LAcc_y_hist_0                         1.289478
# 7_Acc_magnitude_hist_9                  1.223611
# 0_LAcc_magnitude_q2                     1.211172
# 11_LAcc_x_hist_0                        1.207799
# 8_Acc_magnitude_entropy                 1.203455
# 9_Acc_magnitude_Acc_derotated_z_cov     1.179862
# 6_LAcc_y_hist_9                         1.144226
# 13_LAcc_x_max_signal1                   1.144161
# 19_LAcc_z_hist_9                        1.139800
# 5_Acc_y_Acc_magnitude_cov               1.108322
# 3_LAcc_y_q1                             1.103247
# 17_Acc_magnitude_hist_1                 1.068839
# 18_Acc_derotated_z_max_signal2          1.063860
# 21_Acc_z_Acc_magnitude_cov              1.045363
# 20_LAcc_y_Acc_magnitude_cov             1.015995
# 26_LAcc_z_Acc_magnitude_cov             1.011290
# 16_Acc_magnitude_LAcc_magnitude_cov     1.008247
# 27_LAcc_magnitude_hist_9                1.007548
# 23_LAcc_x_hist_9                        1.005974
# 24_Acc_magnitude_hist_2                 0.995404
# 55_LAcc_z_LAcc_y_cov                    0.987098
# 33_LAcc_z_Acc_y_cov                     0.956820
# 30_Acc_z_LAcc_z_cov                     0.952481
# 28_Gyr_x_Acc_magnitude_cov              0.949884
# 40_LAcc_x_Acc_magnitude_cov             0.945402
# 37_Gyr_y_Acc_magnitude_cov              0.941089
# 34_Gyr_y_LAcc_y_cov                     0.934071
# 38_Gyr_x_LAcc_z_cov                     0.933215
# 25_Gyr_y_hist_0                         0.932111
# 14_Acc_magnitude_Gyr_magnitude_cov      0.919144
# 49_Acc_z_LAcc_y_cov                     0.913752
# 36_LAcc_y_Acc_derotated_z_cov           0.912567
# 43_LAcc_x_LAcc_z_cov                    0.910021
# 15_Acc_y_LAcc_y_cov                     0.909133
# 12_Acc_y_hist_9                         0.907584
# 39_Gyr_x_LAcc_y_cov                     0.901809
# 45_Gyr_x_LAcc_x_cov                     0.901320
# 42_LAcc_x_LAcc_y_cov                    0.900770
# 60_LAcc_z_Gyr_y_cov                     0.899941
# 35_LAcc_x_Acc_y_cov                     0.896341
# 32_Gyr_y_max_signal1                    0.894065
# 52_Acc_x_LAcc_x_cov                     0.893257
# 74_Gyr_x_Acc_derotated_z_cov            0.890854
# 66_Acc_derotated_x_hist_0               0.890091
# 48_Acc_x_Acc_magnitude_cov              0.885115
# 68_Acc_derotated_y_max_signal2          0.882130
# 58_Gyr_x_hist_0                         0.878264
# 90_Acc_z_LAcc_x_cov                     0.874172
# 67_Gyr_z_LAcc_z_cov                     0.873381
# 41_Acc_derotated_z_hist_9               0.873282
# 46_Acc_x_LAcc_y_cov                     0.872339
# 98_LAcc_x_Gyr_y_cov                     0.871958
# 61_Gyr_z_Acc_magnitude_cov              0.871533
# 65_Acc_magnitude_Acc_derotated_y_cov    0.870663
# 75_Acc_x_LAcc_z_cov                     0.870136
# 51_Acc_magnitude_Acc_derotated_x_cov    0.867695
# 54_LAcc_y_max                           0.866037
# 83_Acc_z_Gyr_z_cov                      0.864297
# 94_Acc_derotated_y_hist_0               0.863595
# 22_Acc_magnitude_Gra_magnitude_cov      0.860648
# 59_Gyr_z_LAcc_y_cov                     0.857788
# 81_Acc_x_Gyr_x_cov                      0.849476
# 63_Gyr_x_Acc_y_cov                      0.843498
# 57_Acc_x_hist_9                         0.836924
# 79_LAcc_x_max                           0.836878
# 89_Gra_z_LAcc_y_cov                     0.832565
# 88_LAcc_x_hist_1                        0.831353
# 80_Acc_z_Gyr_x_cov                      0.830138
# 91_Gyr_z_LAcc_x_cov                     0.825816
# 99_LAcc_z_Gyr_magnitude_cov             0.823683
# 76_LAcc_y_hist_2                        0.819903
# 31_LAcc_y_Gyr_magnitude_cov             0.819770
# 96_LAcc_y_Acc_derotated_x_cov           0.817397
# 72_Acc_y_Gyr_y_cov                      0.809538
# 73_LAcc_x_Gra_z_cov                     0.801191
# 29_LAcc_z_pitch_cov                     0.798347
# 69_LAcc_y_pitch_cov                     0.791902
# 87_Gyr_z_hist_0                         0.790369
# 93_LAcc_x_Gyr_magnitude_cov             0.784929
# 47_LAcc_y_Gra_magnitude_cov             0.781430
# 56_Acc_magnitude_pitch_cov              0.764917
# 62_Gyr_z_max_signal3                    0.762076
# 92_Gyr_magnitude_hist_9                 0.756561
# 64_Acc_y_Acc_derotated_z_cov            0.755642
# 85_LAcc_x_pitch_cov                     0.747900
# 97_Gyr_x_Gyr_z_cov                      0.723636
# 71_Acc_y_LAcc_magnitude_cov             0.722271
# 70_Gra_magnitude_energy                 0.704385
# 82_Gyr_x_pitch_cov                      0.696289
# 53_Acc_y_Gra_magnitude_cov              0.686311
# 77_Acc_y_Gyr_magnitude_cov              0.677368
# 95_LAcc_y_Mag_z_cov                     0.652322
# 44_Gra_y_energy                         0.651769
# 84_pitch_max_signal1                    0.613628
# 86_pitch_hist_0                         0.607225
# 78_Acc_magnitude_q1                     0.605630
# 50_Acc_y_mean                           0.481464
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_reduced_hmm_recurrent_gaussian_10000_10000_random.pickle_validation
# ====================================================================================================
# 1_Acc_magnitude_hist_0                  1.271192
# 2_Acc_magnitude_max_signal1             1.271000
# 10_LAcc_z_hist_0                        1.223157
# 4_LAcc_y_hist_0                         1.204241
# 7_Acc_magnitude_hist_9                  1.172354
# 11_LAcc_x_hist_0                        1.156644
# 0_LAcc_magnitude_q2                     1.112277
# 5_Acc_y_Acc_magnitude_cov               1.107134
# 9_Acc_magnitude_Acc_derotated_z_cov     1.106745
# 13_LAcc_x_max_signal1                   1.102401
# 8_Acc_magnitude_entropy                 1.099228
# 19_LAcc_z_hist_9                        1.085385
# 6_LAcc_y_hist_9                         1.084726
# 17_Acc_magnitude_hist_1                 1.029647
# 3_LAcc_y_q1                             1.015986
# 18_Acc_derotated_z_max_signal2          1.014616
# 27_LAcc_magnitude_hist_9                0.992066
# 21_Acc_z_Acc_magnitude_cov              0.991259
# 20_LAcc_y_Acc_magnitude_cov             0.991099
# 26_LAcc_z_Acc_magnitude_cov             0.984740
# 16_Acc_magnitude_LAcc_magnitude_cov     0.980144
# ...
# 82_Gyr_x_pitch_cov                      0.562451
# 78_Acc_magnitude_q1                     0.540365
# 84_pitch_max_signal1                    0.505727
# 86_pitch_hist_0                         0.496590
# 50_Acc_y_mean                           0.433218
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_reduced_hmm_recurrent_diagonal_ar_10000_10000_random.pickle_validation
# ====================================================================================================
# 1_Acc_magnitude_hist_0                  1.151126
# 2_Acc_magnitude_max_signal1             1.145125
# 10_LAcc_z_hist_0                        1.122343
# 4_LAcc_y_hist_0                         1.110181
# 0_LAcc_magnitude_q2                     1.059622
# 7_Acc_magnitude_hist_9                  1.054365
# 11_LAcc_x_hist_0                        1.046507
# 9_Acc_magnitude_Acc_derotated_z_cov     1.020536
# 8_Acc_magnitude_entropy                 1.017839
# 5_Acc_y_Acc_magnitude_cov               1.005862
# 13_LAcc_x_max_signal1                   0.998552
# 19_LAcc_z_hist_9                        0.998357
# 6_LAcc_y_hist_9                         0.997960
# 3_LAcc_y_q1                             0.969652
# 18_Acc_derotated_z_max_signal2          0.959389
# 16_Acc_magnitude_LAcc_magnitude_cov     0.931502
# 17_Acc_magnitude_hist_1                 0.931244
# 27_LAcc_magnitude_hist_9                0.916839
# 21_Acc_z_Acc_magnitude_cov              0.916484
# 55_LAcc_z_LAcc_y_cov                    0.905321
# 26_LAcc_z_Acc_magnitude_cov             0.900406
# 23_LAcc_x_hist_9                        0.896439
# 20_LAcc_y_Acc_magnitude_cov             0.896228
# 25_Gyr_y_hist_0                         0.878347
# 28_Gyr_x_Acc_magnitude_cov              0.876693
# 14_Acc_magnitude_Gyr_magnitude_cov      0.874947
# 24_Acc_magnitude_hist_2                 0.874090
# 30_Acc_z_LAcc_z_cov                     0.864547
# 34_Gyr_y_LAcc_y_cov                     0.859812
# 38_Gyr_x_LAcc_z_cov                     0.851389
# 37_Gyr_y_Acc_magnitude_cov              0.849907
# 33_LAcc_z_Acc_y_cov                     0.848350
# 40_LAcc_x_Acc_magnitude_cov             0.840472
# 32_Gyr_y_max_signal1                    0.840285
# 49_Acc_z_LAcc_y_cov                     0.829813
# 36_LAcc_y_Acc_derotated_z_cov           0.826791
# 39_Gyr_x_LAcc_y_cov                     0.826667
# 42_LAcc_x_LAcc_y_cov                    0.825726
# 74_Gyr_x_Acc_derotated_z_cov            0.824011
# 35_LAcc_x_Acc_y_cov                     0.823713
# 68_Acc_derotated_y_max_signal2          0.822694
# 15_Acc_y_LAcc_y_cov                     0.822577
# 60_LAcc_z_Gyr_y_cov                     0.822242
# 12_Acc_y_hist_9                         0.821575
# 43_LAcc_x_LAcc_z_cov                    0.821567
# 45_Gyr_x_LAcc_x_cov                     0.821283
# 52_Acc_x_LAcc_x_cov                     0.812187
# 22_Acc_magnitude_Gra_magnitude_cov      0.809761
# 66_Acc_derotated_x_hist_0               0.807289
# 41_Acc_derotated_z_hist_9               0.806660
# 67_Gyr_z_LAcc_z_cov                     0.806364
# 58_Gyr_x_hist_0                         0.801520
# 54_LAcc_y_max                           0.799260
# 61_Gyr_z_Acc_magnitude_cov              0.799112
# 59_Gyr_z_LAcc_y_cov                     0.798969
# 51_Acc_magnitude_Acc_derotated_x_cov    0.796923
# 65_Acc_magnitude_Acc_derotated_y_cov    0.793268
# 48_Acc_x_Acc_magnitude_cov              0.791343
# 98_LAcc_x_Gyr_y_cov                     0.790096
# 46_Acc_x_LAcc_y_cov                     0.786254
# 63_Gyr_x_Acc_y_cov                      0.779498
# 89_Gra_z_LAcc_y_cov                     0.778407
# 94_Acc_derotated_y_hist_0               0.776806
# 90_Acc_z_LAcc_x_cov                     0.774469
# 31_LAcc_y_Gyr_magnitude_cov             0.773780
# 79_LAcc_x_max                           0.771993
# 99_LAcc_z_Gyr_magnitude_cov             0.771768
# 75_Acc_x_LAcc_z_cov                     0.766837
# 83_Acc_z_Gyr_z_cov                      0.766054
# 81_Acc_x_Gyr_x_cov                      0.765809
# 47_LAcc_y_Gra_magnitude_cov             0.755683
# 88_LAcc_x_hist_1                        0.755589
# 57_Acc_x_hist_9                         0.754988
# 80_Acc_z_Gyr_x_cov                      0.753846
# 91_Gyr_z_LAcc_x_cov                     0.751018
# 96_LAcc_y_Acc_derotated_x_cov           0.750547
# 73_LAcc_x_Gra_z_cov                     0.746816
# 76_LAcc_y_hist_2                        0.746105
# 93_LAcc_x_Gyr_magnitude_cov             0.742674
# 29_LAcc_z_pitch_cov                     0.737463
# 87_Gyr_z_hist_0                         0.737210
# 69_LAcc_y_pitch_cov                     0.737020
# 72_Acc_y_Gyr_y_cov                      0.735714
# 62_Gyr_z_max_signal3                    0.730581
# 64_Acc_y_Acc_derotated_z_cov            0.709602
# 56_Acc_magnitude_pitch_cov              0.708508
# 92_Gyr_magnitude_hist_9                 0.704950
# 85_LAcc_x_pitch_cov                     0.694458
# 70_Gra_magnitude_energy                 0.686282
# 97_Gyr_x_Gyr_z_cov                      0.677424
# 53_Acc_y_Gra_magnitude_cov              0.668373
# 71_Acc_y_LAcc_magnitude_cov             0.666734
# 77_Acc_y_Gyr_magnitude_cov              0.650058
# 82_Gyr_x_pitch_cov                      0.634057
# 44_Gra_y_energy                         0.631116
# 95_LAcc_y_Mag_z_cov                     0.617828
# 84_pitch_max_signal1                    0.572390
# 86_pitch_hist_0                         0.563835
# 78_Acc_magnitude_q1                     0.561198
# 50_Acc_y_mean                           0.463170
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_reduced_hmm_standard_diagonal_robust_ar_10000_10000_random.pickle_validation
# ====================================================================================================
# 1_Acc_magnitude_hist_0                  1.325264
# 2_Acc_magnitude_max_signal1             1.315428
# 10_LAcc_z_hist_0                        1.241549
# 4_LAcc_y_hist_0                         1.211257
# 7_Acc_magnitude_hist_9                  1.196246
# 11_LAcc_x_hist_0                        1.159017
# 0_LAcc_magnitude_q2                     1.154566
# 9_Acc_magnitude_Acc_derotated_z_cov     1.130374
# 8_Acc_magnitude_entropy                 1.125589
# 13_LAcc_x_max_signal1                   1.094346
# 5_Acc_y_Acc_magnitude_cov               1.084853
# 19_LAcc_z_hist_9                        1.082384
# 6_LAcc_y_hist_9                         1.079208
# 3_LAcc_y_q1                             1.058950
# 18_Acc_derotated_z_max_signal2          1.052780
# 17_Acc_magnitude_hist_1                 1.039908
# 21_Acc_z_Acc_magnitude_cov              0.993155
# 27_LAcc_magnitude_hist_9                0.979137
# 24_Acc_magnitude_hist_2                 0.970338
# 26_LAcc_z_Acc_magnitude_cov             0.968876
# 16_Acc_magnitude_LAcc_magnitude_cov     0.966932
# 20_LAcc_y_Acc_magnitude_cov             0.961772
# 23_LAcc_x_hist_9                        0.957231
# 55_LAcc_z_LAcc_y_cov                    0.955361
# 28_Gyr_x_Acc_magnitude_cov              0.930590
# 30_Acc_z_LAcc_z_cov                     0.929056
# 40_LAcc_x_Acc_magnitude_cov             0.916682
# 37_Gyr_y_Acc_magnitude_cov              0.906114
# 34_Gyr_y_LAcc_y_cov                     0.905317
# 33_LAcc_z_Acc_y_cov                     0.904760
# 38_Gyr_x_LAcc_z_cov                     0.893649
# 49_Acc_z_LAcc_y_cov                     0.892999
# 25_Gyr_y_hist_0                         0.890758
# 39_Gyr_x_LAcc_y_cov                     0.878956
# 43_LAcc_x_LAcc_z_cov                    0.878369
# 45_Gyr_x_LAcc_x_cov                     0.876625
# 42_LAcc_x_LAcc_y_cov                    0.873147
# 14_Acc_magnitude_Gyr_magnitude_cov      0.871610
# 36_LAcc_y_Acc_derotated_z_cov           0.870691
# 41_Acc_derotated_z_hist_9               0.868146
# 60_LAcc_z_Gyr_y_cov                     0.865830
# 74_Gyr_x_Acc_derotated_z_cov            0.861505
# 12_Acc_y_hist_9                         0.861496
# 66_Acc_derotated_x_hist_0               0.857552
# 15_Acc_y_LAcc_y_cov                     0.856829
# 68_Acc_derotated_y_max_signal2          0.856220
# 48_Acc_x_Acc_magnitude_cov              0.854301
# 98_LAcc_x_Gyr_y_cov                     0.853645
# 35_LAcc_x_Acc_y_cov                     0.852155
# 52_Acc_x_LAcc_x_cov                     0.850882
# 90_Acc_z_LAcc_x_cov                     0.847472
# 67_Gyr_z_LAcc_z_cov                     0.847331
# 61_Gyr_z_Acc_magnitude_cov              0.842987
# 32_Gyr_y_max_signal1                    0.840569
# 59_Gyr_z_LAcc_y_cov                     0.836642
# 65_Acc_magnitude_Acc_derotated_y_cov    0.836380
# 58_Gyr_x_hist_0                         0.832899
# 51_Acc_magnitude_Acc_derotated_x_cov    0.832333
# 54_LAcc_y_max                           0.829167
# 22_Acc_magnitude_Gra_magnitude_cov      0.826929
# 83_Acc_z_Gyr_z_cov                      0.825171
# 46_Acc_x_LAcc_y_cov                     0.824935
# 94_Acc_derotated_y_hist_0               0.823283
# 75_Acc_x_LAcc_z_cov                     0.822416
# 63_Gyr_x_Acc_y_cov                      0.813526
# 79_LAcc_x_max                           0.813273
# 81_Acc_x_Gyr_x_cov                      0.812384
# 80_Acc_z_Gyr_x_cov                      0.800843
# 88_LAcc_x_hist_1                        0.799617
# 89_Gra_z_LAcc_y_cov                     0.798268
# 91_Gyr_z_LAcc_x_cov                     0.795848
# 57_Acc_x_hist_9                         0.783997
# 99_LAcc_z_Gyr_magnitude_cov             0.783232
# 96_LAcc_y_Acc_derotated_x_cov           0.780235
# 76_LAcc_y_hist_2                        0.780056
# 31_LAcc_y_Gyr_magnitude_cov             0.778361
# 72_Acc_y_Gyr_y_cov                      0.766377
# 47_LAcc_y_Gra_magnitude_cov             0.765314
# 87_Gyr_z_hist_0                         0.764127
# 73_LAcc_x_Gra_z_cov                     0.762517
# 69_LAcc_y_pitch_cov                     0.757704
# 29_LAcc_z_pitch_cov                     0.752091
# 62_Gyr_z_max_signal3                    0.748601
# 93_LAcc_x_Gyr_magnitude_cov             0.744062
# 56_Acc_magnitude_pitch_cov              0.726755
# 64_Acc_y_Acc_derotated_z_cov            0.726552
# 85_LAcc_x_pitch_cov                     0.711169
# 92_Gyr_magnitude_hist_9                 0.709182
# 97_Gyr_x_Gyr_z_cov                      0.693989
# 71_Acc_y_LAcc_magnitude_cov             0.687597
# 70_Gra_magnitude_energy                 0.684925
# 82_Gyr_x_pitch_cov                      0.661978
# 53_Acc_y_Gra_magnitude_cov              0.657136
# 77_Acc_y_Gyr_magnitude_cov              0.647624
# 44_Gra_y_energy                         0.621264
# 95_LAcc_y_Mag_z_cov                     0.618128
# 78_Acc_magnitude_q1                     0.597399
# 84_pitch_max_signal1                    0.567706
# 86_pitch_hist_0                         0.567584
# 50_Acc_y_mean                           0.459941
# dtype: float64
# ----------------------------------------------------------------------------------------------------
#
# huawei_reduced_hmm_standard_robust_ar_10000_10000_random.pickle_validation
# ====================================================================================================
# 2_Acc_magnitude_max_signal1             1.309713
# 1_Acc_magnitude_hist_0                  1.283936
# 10_LAcc_z_hist_0                        1.196648
# 7_Acc_magnitude_hist_9                  1.186068
# 4_LAcc_y_hist_0                         1.175046
# 0_LAcc_magnitude_q2                     1.130506
# 9_Acc_magnitude_Acc_derotated_z_cov     1.125440
# 11_LAcc_x_hist_0                        1.115669
# 8_Acc_magnitude_entropy                 1.091905
# 5_Acc_y_Acc_magnitude_cov               1.076362
# 19_LAcc_z_hist_9                        1.066051
# 18_Acc_derotated_z_max_signal2          1.065754
# 13_LAcc_x_max_signal1                   1.061888
# 6_LAcc_y_hist_9                         1.061225
# 17_Acc_magnitude_hist_1                 1.055841
# 3_LAcc_y_q1                             1.031724
# 21_Acc_z_Acc_magnitude_cov              0.994876
# 24_Acc_magnitude_hist_2                 0.977222
# 27_LAcc_magnitude_hist_9                0.964547
# 26_LAcc_z_Acc_magnitude_cov             0.963471
# 16_Acc_magnitude_LAcc_magnitude_cov     0.956970
# 55_LAcc_z_LAcc_y_cov                    0.950502
# 20_LAcc_y_Acc_magnitude_cov             0.946717
# 23_LAcc_x_hist_9                        0.940112
# 28_Gyr_x_Acc_magnitude_cov              0.929543
# 25_Gyr_y_hist_0                         0.920808
# 30_Acc_z_LAcc_z_cov                     0.916110
# 40_LAcc_x_Acc_magnitude_cov             0.909780
# 14_Acc_magnitude_Gyr_magnitude_cov      0.907865
# 41_Acc_derotated_z_hist_9               0.906099
# 33_LAcc_z_Acc_y_cov                     0.904270
# 37_Gyr_y_Acc_magnitude_cov              0.893225
# 34_Gyr_y_LAcc_y_cov                     0.884823
# 32_Gyr_y_max_signal1                    0.883770
# 38_Gyr_x_LAcc_z_cov                     0.882114
# 43_LAcc_x_LAcc_z_cov                    0.880182
# 49_Acc_z_LAcc_y_cov                     0.880132
# 74_Gyr_x_Acc_derotated_z_cov            0.873639
# 39_Gyr_x_LAcc_y_cov                     0.871439
# 58_Gyr_x_hist_0                         0.868659
# 45_Gyr_x_LAcc_x_cov                     0.867571
# 15_Acc_y_LAcc_y_cov                     0.865797
# 36_LAcc_y_Acc_derotated_z_cov           0.861352
# 68_Acc_derotated_y_max_signal2          0.856125
# 66_Acc_derotated_x_hist_0               0.855200
# 12_Acc_y_hist_9                         0.855022
# 42_LAcc_x_LAcc_y_cov                    0.854141
# 35_LAcc_x_Acc_y_cov                     0.853650
# 54_LAcc_y_max                           0.847396
# 52_Acc_x_LAcc_x_cov                     0.847308
# 60_LAcc_z_Gyr_y_cov                     0.842604
# 48_Acc_x_Acc_magnitude_cov              0.834119
# 67_Gyr_z_LAcc_z_cov                     0.833317
# 61_Gyr_z_Acc_magnitude_cov              0.833236
# 59_Gyr_z_LAcc_y_cov                     0.831473
# 90_Acc_z_LAcc_x_cov                     0.831242
# 51_Acc_magnitude_Acc_derotated_x_cov    0.830689
# 65_Acc_magnitude_Acc_derotated_y_cov    0.830543
# 98_LAcc_x_Gyr_y_cov                     0.830136
# 79_LAcc_x_max                           0.824112
# 94_Acc_derotated_y_hist_0               0.824026
# 46_Acc_x_LAcc_y_cov                     0.822761
# 89_Gra_z_LAcc_y_cov                     0.822550
# 83_Acc_z_Gyr_z_cov                      0.821336
# 63_Gyr_x_Acc_y_cov                      0.819650
# 22_Acc_magnitude_Gra_magnitude_cov      0.819341
# 75_Acc_x_LAcc_z_cov                     0.818094
# 31_LAcc_y_Gyr_magnitude_cov             0.815209
# 99_LAcc_z_Gyr_magnitude_cov             0.808562
# 81_Acc_x_Gyr_x_cov                      0.806700
# 80_Acc_z_Gyr_x_cov                      0.803351
# 29_LAcc_z_pitch_cov                     0.803031
# 88_LAcc_x_hist_1                        0.796761
# 87_Gyr_z_hist_0                         0.792214
# 57_Acc_x_hist_9                         0.789383
# 91_Gyr_z_LAcc_x_cov                     0.789074
# 69_LAcc_y_pitch_cov                     0.783951
# 73_LAcc_x_Gra_z_cov                     0.782250
# 76_LAcc_y_hist_2                        0.780794
# 72_Acc_y_Gyr_y_cov                      0.773282
# 47_LAcc_y_Gra_magnitude_cov             0.772560
# 93_LAcc_x_Gyr_magnitude_cov             0.769083
# 96_LAcc_y_Acc_derotated_x_cov           0.766399
# 92_Gyr_magnitude_hist_9                 0.765134
# 62_Gyr_z_max_signal3                    0.761297
# 56_Acc_magnitude_pitch_cov              0.753562
# 64_Acc_y_Acc_derotated_z_cov            0.750522
# 85_LAcc_x_pitch_cov                     0.728163
# 97_Gyr_x_Gyr_z_cov                      0.714959
# 82_Gyr_x_pitch_cov                      0.707402
# 71_Acc_y_LAcc_magnitude_cov             0.692621
# 70_Gra_magnitude_energy                 0.689676
# 44_Gra_y_energy                         0.681310
# 53_Acc_y_Gra_magnitude_cov              0.678239
# 77_Acc_y_Gyr_magnitude_cov              0.650654
# 86_pitch_hist_0                         0.624673
# 84_pitch_max_signal1                    0.619970
# 95_LAcc_y_Mag_z_cov                     0.607959
# 78_Acc_magnitude_q1                     0.607592
# 50_Acc_y_mean                           0.505008
# dtype: float64
# ----------------------------------------------------------------------------------------------------

# %%
plot_states(y_train, models[0]["most_likely"], "estimated", 0 )

# %%
accuracy_score(y_train, models[1]["most_likely"])

# %%
confusion_matrix(y_train, models[1]["most_likely"])

# %%
posterior_x = posterior.mean_continuous_states[0]
most_likely = rslds.most_likely_states(posterior_x, X_train)

# %%
y_train

# %%
# try:
perm = find_permutation(y_train.astype(int), most_likely)
rslds.permute(perm)
# except:
#     logging.error("Prediction exception")

# %%
z_est = rslds.most_likely_states(posterior_x, X_train)
plot_states(y_train, z_est, "Predicted", 0)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_score(y_train, z_est)

# %%
confusion_matrix(y_train, z_est)

# %%
print(models[0]['hmm_lls'])

# %%
plt.plot(models[1]['hmm_lls'][1000:])

# %%
"test"
